# %% [markdown]
# Pretraining prototype 1:
#
# - Training time: 2h 55m
# - Epochs: 250
# - Total params: 4,958,450 (18.91 MB)
# - Trainable params: 1,651,376 (6.30 MB)
# - Non-trainable params: 4,320 (16.88 KB)
# - Accuracy: 0.43-0.44
# - Val accuracy: 0.33-0.39

# %% [markdown]
# Pretraining prototype 2:
#
# - Training time: 3h 30m
# - Epochs: 250
# - Total params: 629,028 (2.40 MB)
# - Trainable params: 625,820 (2.39 MB)
# - Non-trainable params: 3,208 (12.53 KB)
# - Accuracy: 0.42-0.42
# - Val accuracy: 0.37-0.39

# %% [markdown]
# Pretraining prototype 3:
# - Aborted. Too complex

# %% [markdown]
# Pretraining prototype 4:
#
# - Training time: 53m
# - Epochs: 100
# - Total params: 758,224 (2.89 MB)
# - Trainable params: 754,048 (2.88 MB)
# - Non-trainable params: 4,176 (16.31 KB)
# - Accuracy: 0.56
# - Val accuracy: 0.42

# %% [markdown]
# Pretraining prototype 5:
#
# - Training time: 1h 10m
# - Epochs: 100
# - Total params: 1,396,560 (5.33 MB)
# - Trainable params: 1,390,592 (5.30 MB)
# - Non-trainable params: 5,968 (23.31 KB)
# - Accuracy: 0.54
# - Val accuracy: 0.4

# %% [markdown]
# Pretraining prototype 6:
#
# Comparable to 5
